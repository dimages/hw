# %% [markdown]
# <a href="https://colab.research.google.com/github/dimages/hw/blob/main/Raifhack2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/train.csv'
df = pd.read_csv(file_path)
# Out:
# <ipython-input-3-db0319147120>:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#            city floor     id        lat        lng  \
# 0         Пермь   NaN  COL_0  57.998207  56.292797
# 1        Шатура   NaN  COL_1  55.574284  39.543835
# 2     Ярославль   NaN  COL_2  57.619140  39.850525
# 3   Новокузнецк   NaN  COL_3  53.897083  87.108604
# 4        Москва   NaN  COL_4  55.802590  37.487110
# 5        Самара   NaN  COL_5  53.257900  50.203632
# 6       Лаишево   NaN  COL_6  55.412357  49.561718
# 7       Саратов   NaN  COL_7  51.521416  46.016453
# 8     Краснодар   NaN  COL_8  45.033280  38.976410
# 9  Екатеринбург   NaN  COL_9  56.833660  60.635742
#
#    osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 0                            4                           19
# 1                            3                           24
# 2                            1                           30
# 3                            0                            0
# 4                            1                           23
# ...

# %%
df.shape
# Out:
# (279792, 77)

# %%
df.isna().any().any()
# Out:
# True
